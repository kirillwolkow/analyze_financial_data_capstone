# %% [markdown]
# # Analyze Financial Data Capstone Project from Codecademy

# %% [markdown]
# ## In this project I will analyze the following stocks for a portfolio:

# %% [markdown]
# - Apple
# - Microsoft
# - Tesla
# - Amazon
# - BYD
# - NIO
# - Biontech
# - Netflix
# - Disney

# %% [markdown]
# ## Importing / Downloading Data

# %% [markdown]
# In this project I import the data from the Yahoo Finance API. I take the tickers of the given stocks and take a range from June 2017 to June 2021 (last 5 years).
#
# Further on I import some tools to work like pandas, numpy etc.

# %%
# Importing Tools for work
import pandas as pd
import numpy as np
import datetime
import random
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas_datareader as web
import seaborn as sns

# Importing the Data from Yahoo Finance API
# The data ranges from Jun 01, 2017 to Jun 01, 2021
stocks = ["AAPL", "MSFT", "TSLA", "AMZN", "BYDDF", "NIO", "BNTX", "NFLX", "DIS"]
stocks_data = web.get_data_yahoo(stocks, start = "2017-06-01", end = "2021-06-01")

print(stocks_data.head())
# Out:
# Attributes  Adj Close                                                        \
# Symbols          AAPL       MSFT       TSLA         AMZN     BYDDF NIO BNTX
# Date
# 2017-06-01  36.459702  66.195580  68.073997   995.950012  5.951097 NaN  NaN
# 2017-06-02  36.999996  67.763138  67.970001  1006.729980  5.881435 NaN  NaN
# 2017-06-05  36.638210  68.254150  69.463997  1011.340027  6.010807 NaN  NaN
# 2017-06-06  36.761978  68.480789  70.570000  1003.000000  6.020759 NaN  NaN
# 2017-06-07  36.980961  68.358040  71.930000  1010.070007  6.020759 NaN  NaN
#
# Attributes                              Close  ...        Open       Volume  \
# Symbols           NFLX         DIS       AAPL  ...         DIS         AAPL
# Date                                           ...
# 2017-06-01  162.990005  103.624084  38.294998  ...  107.730003   65616400.0
# 2017-06-02  165.179993  102.637733  38.862499  ...  108.459999  111082800.0
# ...

# %% [markdown]
# ## Calculate Financial Statistics

# %% [markdown]
# In the cells below, there are some key financial statistics which I calculated. The given data is important to show, how the portfolio and the stocks perform.

# %% [markdown]
# ### Adjusted Daily Closing Prices

# %%
# Taking the ADJ Closing Prices and plot them in a graph
stocks_data['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted Price")
plt.title("Stocks Price data")
plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams.update({'font.size': 12})

plt.savefig("stocks_price_data.png")
plt.show()

# Mind that the amazon stock has a great impact on the graph, because of its higher value.

# %% [markdown]
# ### Adjusted Daily Closing Prices Seperated

# %%
# Taking the ADJ Closing Prices in subplots for every stock, to better see the performance of each stock
# creating figure and size it
fig = plt.figure(figsize = (32, 20))
plt.rcParams.update({'font.size': 11})
fig.set_figheight(25)
fig.set_figwidth(15)

# Creating subplots
ax1 = fig.add_subplot(521)
ax2 = fig.add_subplot(522)
ax3 = fig.add_subplot(523)
ax4 = fig.add_subplot(524)
ax5 = fig.add_subplot(525)
ax6 = fig.add_subplot(526)
ax7 = fig.add_subplot(527)
ax8 = fig.add_subplot(528)
ax9 = fig.add_subplot(529)
ax1.plot(stocks_data['Adj Close']['AAPL'])
ax1.set_title("Apple")
ax1.tick_params(axis='x', rotation=45)
ax2.plot(stocks_data['Adj Close']['MSFT'])
ax2.set_title("Microsoft")
ax2.tick_params(axis='x', rotation=45)
ax3.plot(stocks_data['Adj Close']['TSLA'])
ax3.set_title("Tesla")
ax3.tick_params(axis='x', rotation=45)
ax4.plot(stocks_data['Adj Close']['AMZN'])
ax4.set_title("Amazon")
ax4.tick_params(axis='x', rotation=45)
ax5.plot(stocks_data['Adj Close']['BYDDF'])
ax5.set_title("BYD")
ax5.tick_params(axis='x', rotation=45)
ax6.plot(stocks_data['Adj Close']['NIO'])
ax6.set_title("NIO")
ax6.tick_params(axis='x', rotation=45)
ax7.plot(stocks_data['Adj Close']['BNTX'])
ax7.set_title("Biontech")
ax7.tick_params(axis='x', rotation=45)
ax8.plot(stocks_data['Adj Close']['NFLX'])
ax8.set_title("Netflix")
ax8.tick_params(axis='x', rotation=45)
ax9.plot(stocks_data['Adj Close']['DIS'])
ax9.set_title("Disney")
ax9.tick_params(axis='x', rotation=45)

fig.tight_layout(pad=3.0)
plt.savefig("stocks_adj_sep.png")
plt.show()

# %% [markdown]
# Each stock has experienced significant growth in the selected period (5 years). Thus, it should come as no surprise that the portfolio will also post a gain.

# %% [markdown]
# ### Percentage change in stock prices

# %%
# Closing Price
adj_price = stocks_data["Adj Close"]
print(adj_price.head())

# Log of percentage change
log_stocks_data = adj_price.pct_change().apply(lambda x: np.log(1+x))
print(log_stocks_data.head())
# Out:
# Symbols          AAPL       MSFT       TSLA         AMZN     BYDDF  NIO  BNTX  \
# Date
# 2017-06-01  36.459702  66.195580  68.073997   995.950012  5.951097  NaN   NaN
# 2017-06-02  36.999996  67.763138  67.970001  1006.729980  5.881435  NaN   NaN
# 2017-06-05  36.638210  68.254150  69.463997  1011.340027  6.010807  NaN   NaN
# 2017-06-06  36.761978  68.480789  70.570000  1003.000000  6.020759  NaN   NaN
# 2017-06-07  36.980961  68.358040  71.930000  1010.070007  6.020759  NaN   NaN
#
# Symbols           NFLX         DIS
# Date
# 2017-06-01  162.990005  103.624084
# 2017-06-02  165.179993  102.637733
# 2017-06-05  165.059998  102.005707
# 2017-06-06  165.169998  101.028938
# 2017-06-07  165.610001  101.431129
# Symbols         AAPL      MSFT      TSLA      AMZN     BYDDF  NIO  BNTX  \
# Date
# 2017-06-01       NaN       NaN       NaN       NaN       NaN  NaN   NaN
# 2017-06-02  0.014710  0.023405 -0.001529  0.010766 -0.011775  NaN   NaN
# ...

# %% [markdown]
# ### Variance

# %%
# Variance
var = log_stocks_data.var()
print(var)

plt.plot(var, linestyle = "dashed", marker='o', linewidth = 2)
plt.xlabel("Stocks")
plt.ylabel("Variance")
plt.title("Variance")
plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams.update({'font.size': 12})
plt.xticks(rotation = 45)

plt.savefig("variance.png")

plt.show()
# Out:
# Symbols
# AAPL     0.000424
# MSFT     0.000349
# TSLA     0.001621
# AMZN     0.000385
# BYDDF    0.001066
# NIO      0.004087
# BNTX     0.005079
# NFLX     0.000664
# DIS      0.000375
# dtype: float64

# %% [markdown]
# The variance in prices of stocks are an important indicator of how volatile this investment will be (how returns can fluctuate).
#
# As you see, Biontech and NIO have the highest variance, thus Microsoft and Disney have the lowest.
#
# It can be calculated for each company by using built in .var() function. Under the hood, the formula implemented by this function is given by:

# %% [markdown]
# $$s^2 = \frac{\displaystyle\sum_{i=1}^{N}(x_i - \bar x)^2} {N-1}$$

# %% [markdown]
# ### Volatility

# %%
# Volatility
adj_price.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250)).plot(kind='bar', title="Volatility")
plt.xlabel("Stocks")
plt.ylabel("Volatility")
plt.rcParams['figure.figsize'] = [10, 10]
plt.rcParams.update({'font.size': 12})
plt.xticks(rotation = 45)

plt.savefig("volatility.png")

# %% [markdown]
# Similar to variance, Biontech and NIO have the highest volatility. And the shares, Disney and Microsoft the lowest.
#
# The volatility was calculated with the following formula:

# %% [markdown]
# $$s = \sqrt\frac{\displaystyle\sum_{i=1}^{N}(x_i - \bar x)^2} {N-1}$$

# %% [markdown]
# ### Covariance

# %%
# Covariance
cov = log_stocks_data.cov()
print(cov)

plt.figure(figsize=(16, 6))
cov_heatmap = sns.heatmap(cov, annot=True, cmap='BrBG', annot_kws={"size": 12})
cov_heatmap.set_title('Covariance Heatmap', fontdict={'fontsize':12}, pad=5);
fig.tight_layout()
plt.savefig("cov_heatmap.png")

plt.show()
# Out:
# Symbols      AAPL      MSFT      TSLA      AMZN     BYDDF       NIO      BNTX  \
# Symbols
# AAPL     0.000424  0.000291  0.000359  0.000263  0.000229  0.000385  0.000288
# MSFT     0.000291  0.000349  0.000334  0.000268  0.000212  0.000319  0.000264
# TSLA     0.000359  0.000334  0.001621  0.000312  0.000409  0.000867 -0.000097
# AMZN     0.000263  0.000268  0.000312  0.000385  0.000192  0.000340  0.000184
# BYDDF    0.000229  0.000212  0.000409  0.000192  0.001066  0.000864  0.000222
# NIO      0.000385  0.000319  0.000867  0.000340  0.000864  0.004087  0.000336
# BNTX     0.000288  0.000264 -0.000097  0.000184  0.000222  0.000336  0.005079
# NFLX     0.000266  0.000277  0.000363  0.000330  0.000224  0.000343  0.000054
# DIS      0.000170  0.000174  0.000192  0.000120  0.000148  0.000210  0.000195
#
# Symbols      NFLX       DIS
# Symbols
# AAPL     0.000266  0.000170
# MSFT     0.000277  0.000174
# TSLA     0.000363  0.000192
# AMZN     0.000330  0.000120
# ...

# %% [markdown]
# Covariance measures the directional relationship between the returns on two assets.
#
# A positive covariance means that returns of the two assets move together while a negative covariance means they move inversely. Risk and volatility can be reduced in a portfolio by pairing assets that have a negative covariance.
#
# Assets can have a positive covariance, negative covariance, or no covariance:
#
# - Positive covariance — when one asset increases in value, the other usually increases in value. The covariance value will be greater than 0.
# - Negative covariance — when one asset increases in value, the other usually decreases in value. The covariance value will be less than 0.
# - Uncorrelated assets — when there is no quantifiable pattern to the response of two assets. The covariance value is equal to 0.
#
# The covariance can be calculated with the given formula:

# %% [markdown]
# $$cov_{x,y}=\frac{\sum_{i=1}^{N}(x_{i}-\bar{x})(y_{i}-\bar{y})}{N-1}$$

# %% [markdown]
# ### Correlation

# %%
# Correlation
corr = log_stocks_data.corr()
print(corr)
plt.figure(figsize=(16, 6))
corr_heatmap = sns.heatmap(corr, vmin=-1, vmax=1, annot=True, cmap='BrBG')
corr_heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
plt.savefig("correlation_heatmap.png")

plt.show()
# Out:
# Symbols      AAPL      MSFT      TSLA      AMZN     BYDDF       NIO      BNTX  \
# Symbols
# AAPL     1.000000  0.757059  0.432497  0.651009  0.340688  0.258808  0.160515
# MSFT     0.757059  1.000000  0.444547  0.732324  0.348161  0.240456  0.160269
# TSLA     0.432497  0.444547  1.000000  0.394450  0.310848  0.303609 -0.027275
# AMZN     0.651009  0.732324  0.394450  1.000000  0.300233  0.250829  0.124111
# BYDDF    0.340688  0.348161  0.310848  0.300233  1.000000  0.381744  0.075951
# NIO      0.258808  0.240456  0.303609  0.250829  0.381744  1.000000  0.074198
# BNTX     0.160515  0.160269 -0.027275  0.124111  0.075951  0.074198  1.000000
# NFLX     0.501697  0.575630  0.349801  0.651618  0.266227  0.199647  0.028281
# DIS      0.427341  0.481369  0.246096  0.315869  0.233339  0.148502  0.105428
#
# Symbols      NFLX       DIS
# Symbols
# AAPL     0.501697  0.427341
# MSFT     0.575630  0.481369
# TSLA     0.349801  0.246096
# AMZN     0.651618  0.315869
# ...

# %% [markdown]
# Correlation, in the finance and investment industries, is a statistic that measures the degree to which two securities move in relation to each other. Correlations are used in advanced portfolio management, computed as the correlation coefficient, which has a value that must fall between -1.0 and +1.0.
#
# You can think of correlation as a scaled version of covariance, where the values are restricted to lie between -1 and +1.
#
# A correlation of -1 means negative relation, i.e, if correlation between Asset A and Asset B is -1, if Asset A increases, Asset B decreases.
#
# A correlation of +1 means positive relation, i.e, if correlation between Asset A and Asset B is 1, if Asset A increases, Asset B increases.
#
# A correlation of 0 means no relation, i.e, if correlation between Asset A and Asset B is 0, they dont have any effect on each other.
#
# The correlation can be calculated with following formula:

# %% [markdown]
# $$\rho_{X,Y}=\frac{cov_{X,Y}}{\sigma_{X}\sigma_{Y}}$$

# %% [markdown]
# ## Optimized Portfolio

# %% [markdown]
# Expected returns of an asset are simply the mean of percentage change in its stock prices. So, the value of expected return we obtain here are daily expected returns.
#
# For an yearly expected return value, you will need to resample the data year-wise, as you will see further.
#
# For expected returns, you need to define weights for the assets choosen.
#
# In simpler terms, this means you need to decide what percentage of your total money to you want to hold in each company’s stock.
#
# Usually this decision is done by using the optimization techniques we will discuss later but for now we will consider random weights for our stocks.

# %%
# Define weights for allocation
w = [0.1, 0.1, 0.1, 0.05, 0.05, 0.2, 0.25, 0.03, 0.12]
e_r_ind = log_stocks_data.mean()
print(e_r_ind)

# Total expected return
e_r = (e_r_ind*w).sum()
print(e_r)
# Out:
# Symbols
# AAPL     0.001219
# MSFT     0.001311
# TSLA     0.002202
# AMZN     0.001166
# BYDDF    0.001414
# NIO      0.002721
# BNTX     0.006487
# NFLX     0.001112
# DIS      0.000542
# dtype: float64
# 0.0028665660398849995

# %% [markdown]
# ### Portfolio Variance

# %%
# Randomly weighted portfolio's variance
w = {'AAPL': 0.1, 'MSFT': 0.1, 'TSLA': 0.1, 'AMZN': 0.05, 'BYDDF': 0.05, 'NIO': 0.2, 'BNTX': 0.25, 'NFLX': 0.03, 'DIS': 0.12}
port_var = cov.mul(w, axis=0).mul(w, axis=1).sum().sum()
print(port_var)
# Out:
# 0.0007561894863431233

# %% [markdown]
# ###  Yearly and Portfolio returns

# %%
# Yearly returns for individual companies
ind_er = adj_price.resample('Y').last().pct_change().mean()
print(ind_er)

# Portfolio returns
port_w = [0.1, 0.1, 0.1, 0.05, 0.05, 0.2, 0.25, 0.03, 0.12]
port_er = (port_w*ind_er).sum()
print(port_er)
# Out:
# Symbols
# AAPL     0.399589
# MSFT     0.331580
# TSLA     1.911097
# AMZN     0.316350
# BYDDF    0.940199
# NIO      3.541384
# BNTX     1.467422
# NFLX     0.299337
# DIS      0.152753
# dtype: float64
# 1.4294968912643407

# %% [markdown]
# ### Returns and Volatility

# %%
# Volatility is given by the annual standard deviation. We multiply by 250 because there are 250 trading days/year.
ann_sd = adj_price.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
print(ann_sd)

# Creating a table for visualising returns and volatility of assets
assets = pd.concat([ind_er, ann_sd], axis=1)
assets.columns = ['Returns', 'Volatility']
print(assets)
# Out:
# Symbols
# AAPL     0.325688
# MSFT     0.295247
# TSLA     0.636600
# AMZN     0.310275
# BYDDF    0.516331
# NIO      1.010850
# BNTX     1.126806
# NFLX     0.407486
# DIS      0.306242
# dtype: float64
#           Returns  Volatility
# Symbols
# AAPL     0.399589    0.325688
# MSFT     0.331580    0.295247
# TSLA     1.911097    0.636600
# AMZN     0.316350    0.310275
# BYDDF    0.940199    0.516331
# NIO      3.541384    1.010850
# BNTX     1.467422    1.126806
# NFLX     0.299337    0.407486
# DIS      0.152753    0.306242

# %% [markdown]
# ### Efficient Frontier

# %% [markdown]
# This is the aim of going through all the topics above, to plot the efficient frontier. Efficient frontier is a graph with ‘returns’ on the Y-axis and ‘volatility’ on the X-axis. It shows us the maximum return we can get for a set level of volatility, or conversely, the volatility that we need to accept for certain level of returns.
#
# Now we calculate 100'000 different portfolios and plot it on the graph below.
#
# Each point on the line (left edge) represents an optimal portfolio of stocks that maximises the returns for any given level of risk.
#
# The point (portfolios) in the interior are sub-optimal for a given risk level. For every interior point, there is another that offers higher returns for the same risk.
#
# On this graph, you can also see the combination of weights that will give you all possible combinations:
#
# Minimum volatility (left most point)
# Maximum returns (top most point)
# And everything in between.

# %%
# Efficient Frontier
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(adj_price.columns)
num_portfolios = 100000

for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(returns)
    var = cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)
    
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(adj_price.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

portfolios = pd.DataFrame(data)
print(portfolios.head(10)) # Dataframe of the 100'000   portfolios created

# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[10,10], title = "Efficient Frontier")

plt.savefig("efficient_frontier.png")
# Out:
#     Returns  Volatility  AAPL weight  MSFT weight  TSLA weight  AMZN weight  \
# 0  0.843074    0.300884     0.092541     0.127270     0.097047     0.113794
# 1  0.907680    0.308855     0.116566     0.194274     0.047593     0.196161
# 2  1.298489    0.385852     0.077683     0.083337     0.360571     0.002439
# 3  1.292870    0.370629     0.074727     0.134787     0.085307     0.110177
# 4  0.985739    0.323371     0.187155     0.223768     0.122476     0.040472
# 5  0.645828    0.286558     0.112149     0.075225     0.087000     0.125325
# 6  1.161724    0.364609     0.158080     0.225411     0.033187     0.028277
# 7  1.018920    0.336929     0.173982     0.099747     0.188001     0.026042
# 8  1.197535    0.346692     0.231135     0.003965     0.148118     0.070163
# 9  1.050167    0.319156     0.054949     0.174650     0.127564     0.161598
#
#    BYDDF weight  NIO weight  BNTX weight  NFLX weight  DIS weight
# 0      0.161806    0.051246     0.102128     0.137328    0.116841
# ...

# %% [markdown]
# ### Minimum volatility portfolio

# %%
# Portfolio with minimum volatility
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
print(min_vol_port)

# plotting the minimum volatility portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='o', s=500)
plt.title("Minimum Volatility Portfolio")
plt.xlabel("Volatility")
plt.ylabel("Returns")

plt.savefig("e_f_min_vol.png")
# Out:
# Returns         0.399998
# Volatility      0.248938
# AAPL weight     0.162900
# MSFT weight     0.136177
# TSLA weight     0.014957
# AMZN weight     0.220802
# BYDDF weight    0.128034
# NIO weight      0.002344
# BNTX weight     0.007430
# NFLX weight     0.011821
# DIS weight      0.315535
# Name: 92072, dtype: float64

# %% [markdown]
# The red star denotes the most efficient portfolio with minimum volatility.
#
# It is worthwhile to note that any point to the right of efficient frontier boundary is a sup-optimal portfolio.
#
# We found the portfolio with minimum volatility, but you will notice that the return on this portfolio is pretty low. Any sensible investor wants to maximize his return, even if it is a tradeoff with some level of risk.
# The question arises that how do we find this optimal risky portfolio and finally optimize our portfolio to the maximum?
#
# This is done by using a parameter called the Sharpe Ratio.

# %% [markdown]
# ### Sharpe Ratio

# %% [markdown]
# The ratio is the average return earned in excess of the risk-free rate per unit of volatility or total risk. Volatility is a measure of the price fluctuations of an asset or portfolio.
#
# The risk-free rate of return is the return on an investment with zero risk, meaning it’s the return investors could expect for taking no risk.
#
# The optimal risky portfolio is the one with the highest Sharpe ratio. The formula for this ratio is:

# %% [markdown]
# $$sharpe ratio = \frac{R_{p}-R_{f}}{\sigma_{p}}$$

# %% [markdown]
# $R_{p}$ = return of portfolio
#
# $R_{f}$ = risk-free rate
#
# $\sigma_{p}$ = standard deviation of portfolio

# %% [markdown]
# ### Optimal Portfolio

# %% [markdown]
# An optimal risky portfolio can be considered as one that has highest Sharpe ratio.
#
# Let’s find out.

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
print(optimal_risky_port)

# Plotting optimal portfolio
plt.subplots(figsize=(10, 10))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
plt.title("Optimal Portfolio")
plt.xlabel("Volatility")
plt.ylabel("Returns")

plt.savefig("e_f_opt_port.png")
# Out:
# Returns         2.045459
# Volatility      0.504635
# AAPL weight     0.024897
# MSFT weight     0.022039
# TSLA weight     0.310611
# AMZN weight     0.011632
# BYDDF weight    0.144187
# NIO weight      0.312584
# BNTX weight     0.120172
# NFLX weight     0.025920
# DIS weight      0.027958
# Name: 53973, dtype: float64

# %% [markdown]
# You can notice that while the difference in risk between minimum volatility portfolio and optimal risky portfolio is 28%, the difference in returns is a whopping 171%.
# We can plot this point too on the graph of efficient frontier (green star).

# %% [markdown]
# ## Create Your Presentation

# %% [markdown]
# We want to see:
#
# - information about the stocks you utilized (industry, sector, background, news)
# - the key financial statistics about the stocks and how you interpret them
# - a few different portfolio options with the stock weights and why the investor would select that portfolio
# - an overall conclusion to the client about your recommendations

# %%
"""
To Do's:
- search for other useful graphs about given data - DONE
- beautification of graphs - DONE
- information about stocks (industry, sector, background, news) - DONE
- statements after each calculation - DONE
- three different portfolio option - low risk, middle, 'high risk' - DONE (only optimal portfolio, why should you take a weaker one?)
- putting all in a PDF Slideshow - DONE
"""

# %% [markdown]
# ## Share Your Presentation

# %% [markdown]
# 1. Save your presentation as a Google Slide or some other presentation format
# 2. Post your presentation on the Codecademy forum. More details describing how to post your code can be found in the following informational.
#
# Good luck!
